# %% [markdown]
# # IUM Projekt
# Michał Suski 331439
# Michał Szwejk 331445
#
# ## Temat
# Temat: “Fajnie byłoby zorientować się, w których regionach mamy za dużo ofert – psuje to rynek”

# %% [markdown]
# ## 1. Grupowanie na regiony
# Regiony są wyznaczanie na podstawie **współrzędnych geograficznych** za pomocą algorytm `DBSCAN`
